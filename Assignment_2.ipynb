# %% [markdown]
# # k_means clustring

# %%
import numpy as np
import pandas as pd 
import random as rd
import matplotlib.pyplot as plt
from math import sqrt

# %%
data=pd.read_csv("data.csv")
data
# Out:
#       A     B
# 0    12   743
# 1    34   718
# 2     5   882
# 3    68   648
# 4     5   891
# 5   434   781
# 6    66   640
# 7   789   462
# 8    75   442
# 9   234  1121
# 10  887   746
# 11   65   809
# 12    3   456
# 13   21   488
# 14  245    89
# 15  765    90
# 16  453   271
# 17  989   663
# 18  453   543
# 19  523    54
# 20   43    58
# 21  566    91
# 22  876   229
# 23   43    69
# 24  121   694
# 25   79   429
# 26  876   426
# 27  675     1
# 28   54   129
# 29  445   174
# 30  889   362
# 31   11   938
# 32  238   776
# 33  988   128
# 34  812    64
# 35  774   551
# 36  802   992
# 37  991   993
# 38  762   911
# 39  222   928
# 40  892   918
# 41  885    73
# 42  112   646
# 43  445   666
# 44  663   696
# 45  325   969
# 46  874   123
# 47  665   445
# 48  818   842

# %%
df=data[["A","B"]]
plt.scatter(df["A"],df["B"])
plt.title("unclustered data")
plt.xlabel("length")
plt.ylabel("m")
plt.show()

# %%
K=2
Centroids=(df.sample(n=K))
Centroids
# Out:
#       A    B
# 45  325  969
# 44  663  696

# %%
plt.scatter(X["A"],X["B"],c="magenta")
plt.scatter(Centroids["A"],Centroids["B"],c="green")
plt.title("unclustered data")
plt.xlabel("length")
plt.ylabel("meter")
plt.show()

# %%
diff=1
y=0
while(diff!=0):
    x=df
    i=1
    for index1,row_c in Centroids.iterrows():
        E=[]
        for index2,row_d in x.iterrows():
            d1=(row_c["A"]-row_d["B"])**2
            d2=(row_c["B"]-row_d["B"])**2
            d=sqrt(d1+d2)
            E.append(d)
        df[i]=E
        i=i+1
    C=[]
    for index,row in df.iterrows():
        min_dist=row[1]
        pos=1
        for i in range(K):
            if row[i+1]<min_dist:
                min_dist=row[i+1]
                pos=i+1
        C.append(pos)
    df["Cluster"]=C
    Centroids_new=df.groupby(["Cluster"]).mean()[["B","A"]]
    if y== 0:
        diff= 1
        y=y+1
    else:
        diff=(Centroids_new['B']-Centroids['B']).sum()+(Centroids_new['A']-Centroids['A']).sum()
        print(diff.sum())
    Centroids=df.groupby(["Cluster"]).mean()[["B","A"]]
# Out:
# 222.3367346938776
# 0.0

# %%
Centroids
# Out:
#                   B           A
# Cluster
# 1        224.043478  506.260870
# 2        796.346154  401.076923

# %%
color=['pink','magenta']
for k in range(K):
    data=df[df["Cluster"]==k+1]
    plt.scatter(data["A"],data["B"],c=color[k])
plt.scatter(Centroids["A"],Centroids["B"],c='green')
plt.title("clustered data")
plt.xlabel("length")
plt.ylabel("m")
plt.show()
